# %%
pip install face_recognition
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import face_recognition
import matplotlib.pyplot as plt

# %%
img = face_recognition.load_image_file('data/60004190060.jpeg')
# img2 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
face_loc = face_recognition.face_locations(img)[0]

# %%
face_loc
# Out:
# (63, 919, 384, 598)

# %%
face_encod = face_recognition.face_encodings(img)[0]

# %%
face_encod
# Out:
# array([-0.10524091,  0.03168315,  0.02466241, -0.06178471,  0.05353731,
#         0.03894091,  0.0072039 , -0.01583965,  0.21848184, -0.08506878,
#         0.22735323, -0.04968936, -0.2090787 , -0.11252748,  0.01424692,
#         0.0466701 , -0.18986431, -0.11403051, -0.06775513, -0.08892114,
#         0.07036559, -0.00201382, -0.02437814,  0.08548911, -0.16128898,
#        -0.31964213, -0.08028327, -0.13776113,  0.03880596, -0.18218279,
#        -0.03528069,  0.05148702, -0.20294842, -0.05060291, -0.05380654,
#         0.00386387,  0.03572107, -0.02572452,  0.16370347, -0.02598305,
#        -0.11596388, -0.0362521 ,  0.00307516,  0.24442905,  0.16267891,
#         0.00627578, -0.03890701, -0.01054213,  0.04536092, -0.25557464,
#         0.00169464,  0.13966598,  0.07491454,  0.04408677,  0.07856436,
#        -0.15101282, -0.08825494,  0.05184975, -0.10596536,  0.12647049,
#        -0.01793795, -0.10202368, -0.02488043, -0.06066515,  0.14854084,
# ...

# %%
img_test = face_recognition.load_image_file('/content/drive/MyDrive/adele-last-tour.jpg')

# %%
plt.imshow(img_test)

# %%
face_encod_test = face_recognition.face_encodings(img_test)[0]

# %%
results = face_recognition.compare_faces([face_encod],face_encod_test)

# %%
results
# Out:
# [True]

# %%
face_dis = face_recognition.face_distance([face_encod],face_encod_test)

# %%
face_dis
# Out:
# array([0.51956794])

# %%
cv2.putText(img_test,str(results[0]),(500,500),cv2.FONT_HERSHEY_COMPLEX,100,(255,255,255),5)
# Out:
# array([[[66, 70, 71],
#         [67, 71, 72],
#         [68, 72, 73],
#         ...,
#         [83, 90, 96],
#         [83, 90, 96],
#         [83, 90, 96]],
#
#        [[69, 73, 74],
#         [69, 73, 74],
#         [69, 73, 74],
#         ...,
#         [84, 91, 97],
#         [84, 91, 97],
#         [84, 91, 97]],
#
#        [[71, 75, 76],
#         [71, 75, 76],
#         [70, 74, 75],
#         ...,
#         [84, 93, 98],
#         [84, 93, 98],
#         [84, 93, 98]],
#
#        ...,
#
#        [[14, 10,  7],
#         [14, 10,  7],
#         [14, 10,  7],
#         ...,
#         [ 3,  3,  1],
#         [ 3,  3,  1],
#         [ 3,  3,  1]],
#
#        [[14, 10,  7],
#         [14, 10,  7],
#         [14, 10,  7],
#         ...,
#         [ 3,  3,  1],
#         [ 3,  3,  1],
#         [ 3,  3,  1]],
#
#        [[14, 10,  7],
#         [14, 10,  7],
#         [15, 10,  7],
#         ...,
#         [ 3,  4,  0],
#         [ 3,  4,  0],
#         [ 3,  4,  0]]], dtype=uint8)

# %%
plt.imshow(img_test)

# %%
import os

# %%
path='data'

# %%
images = []
classnames = []
lst = os.listdir(path)

# %%
lst
# Out:
# ['60004190005.jpg',
#  '60004190013.jpeg',
#  '60004190059.jpeg',
#  '60004190060.jpeg',
#  '60004190066.jpg']

# %%
for i in lst:
  curImg = cv2.imread(f'{path}/{i}')
  images.append(curImg)
  classnames.append(os.path.splitext(i)[0])

# %%
classnames
images
# Out:
# [array([[[71, 70, 66],
#          [72, 71, 67],
#          [73, 73, 67],
#          ...,
#          [96, 90, 83],
#          [96, 90, 83],
#          [96, 90, 83]],
#
#         [[74, 73, 69],
#          [74, 73, 69],
#          [74, 74, 68],
#          ...,
#          [97, 91, 84],
#          [97, 91, 84],
#          [97, 91, 84]],
#
#         [[76, 75, 71],
#          [76, 75, 71],
#          [75, 75, 69],
#          ...,
#          [98, 93, 84],
#          [98, 93, 84],
#          [98, 93, 84]],
#
#         ...,
#
#         [[ 7, 10, 14],
#          [ 7, 10, 14],
#          [ 7, 10, 15],
#          ...,
#          [ 1,  3,  3],
#          [ 1,  3,  3],
#          [ 1,  3,  3]],
#
#         [[ 7, 10, 14],
#          [ 7, 10, 14],
#          [ 7, 10, 15],
#          ...,
#          [ 1,  3,  3],
#          [ 1,  3,  3],
#          [ 1,  3,  3]],
#
#         [[ 7, 10, 14],
#          [ 7, 10, 14],
#          [ 7, 10, 15],
#          ...,
#          [ 1,  3,  3],
# ...

# %%
def img_encodings(images):
  img_encode = []
  for imgs in images:
    img = cv2.cvtColor(imgs,cv2.COLOR_BGR2RGB)
    encode = face_recognition.face_encodings(img)[0]
    img_encode.append(encode)
  return img_encode

# %%
encode_list = img_encodings(images)
print(encode_list)

# %%
cap = cv2.VideoCapture(0) 

while True: 
    
    ret, frame = cap.read(0) 
    frame_size = cv2.resize(frame,(0,0),None,0.5,0.5)
    frame_size = cv2.cvtColor(frame_size,cv2.COLOR_BGR2RGB)
    face_loc = face_recognition.face_locations(frame_size)
    encode = face_recognition.face_encodings(frame_size,face_loc)
    for encode_face,face_location in zip(encode,face_loc):
      matches = face_recognition.compare_faces(encode_list,encode_face)
      face_dis = face_recognition.face_distance(encode_list,encode_face)
      match_idx = np.argmin(face_dis)
      if matches[match_idx]:
        name = classnames[match_idx].upper()
        print(name)
    cv2.imshow('Video Face Detection', frame) 
    c = cv2.waitKey(10) 
    if c == 27: 
        break 
        
cap.release() 
cv2.destroyAllWindows()
# Out:
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190066
# 60004190066
# 60004190066
# 60004190013
# 60004190066
# 60004190066
# 60004190066
# 60004190066
# 60004190066
# 60004190066
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
# 60004190013
